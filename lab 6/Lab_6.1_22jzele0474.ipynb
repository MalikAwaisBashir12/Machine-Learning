# %% [markdown]
# # Lab 6.1: Linear Regression Using Ohm's Law
#
# **Student Name:** Malik Awais Bashir
# **Registration Number:** 22JZELE0474
# **Course:** Machine Learning Lab
# **Supervisor:** Engr. Irshad Ullah
# **University:** UET Peshawar - Nowshera Campus
#
# ## Lab Overview
# This notebook demonstrates linear regression using a synthetic dataset based on Ohm's Law. The code creates current and voltage values, trains a Linear Regression model, predicts voltage, plots the regression line, and evaluates model performance using common regression metrics.
#
# ## Learning Objectives
# - Generate synthetic current and voltage data using Ohm's Law.
# - Train a Linear Regression model using Scikit-learn.
# - Visualize measured data and the fitted regression line.
# - Evaluate model performance using MAE, RMSE, and R2 score.

# %% [markdown]
# ## Section 1: Problem Setup and Data Generation
# This section introduces the Ohm's Law problem and generates synthetic current-voltage data for regression analysis.

# %% [markdown]
# # Lab 6: Linear Regression & Gradient Descent Visualization
# ## Synthetic Dataset: Ohm's Law (1 kΩ Resistor)

# %% [markdown]
# ### Overview
# In this lab, we will use a **synthetic dataset** based on **Ohm's Law**:
#
# \[
# V = IR
# \]
#
# Where:
# - \( I \) = current (in Amperes)
# - \( R = 1000 \Omega \) (1 kΩ resistor)
# - \( V \) = voltage (in Volts)
#
# We will:
# ✔ Generate synthetic data
# ✔ Fit a Linear Regression model (sklearn)
# ✔ Plot the regression line
# ✔ Visualize gradient descent loss curve
# ✔ Compute MAE, RMSE

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Set true resistance
R_true = 1000  # ohms

# Generate synthetic current (I) between 0 and 10 mA
I = np.linspace(0, 10, 50)  # Amperes

# Generate voltage using Ohm's Law: V = IR
V = R_true * I

# Add small measurement noise
noise = np.random.normal(0, 0.02, size=I.shape)
V_noisy = V + noise

I = I.reshape(-1, 1)

plt.scatter(I, V_noisy, label="Measured Data")
plt.xlabel("Current (A)")
plt.ylabel("Voltage (V)")
plt.title("Ohm's Law Synthetic Data (1 kΩ Resistor)")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Section 2: Model Training and Coefficient Inspection
# The following cells train the Linear Regression model and inspect the slope and intercept learned by the model.

# %%
I_test = np.linspace(0, 0.02, 5)  # Amperes
I_test = I_test.reshape(-1, 1)

v_test= R_true * I_test
noise_test = np.random.normal(0, 0.02, size=I_test.shape)
v_test = v_test + noise_test

# %%
# Fit Linear Regression
# model.fit() solves the linear regression equations using 
# matrix algebra (Normal Equation) to directly compute the optimal slope and intercept without using gradient descent.
model = LinearRegression()
model.fit(I, V_noisy)
# Out:
# LinearRegression()

# %%
print("slope, m",model.coef_ )  # slope (m)
print("intercept, b",model.intercept_ )   # intercept (b)
# Out:
# slope, m [999.99982669]
# intercept, b 4.450382402865216e-05

# %% [markdown]
# ## Section 3: Prediction, Visualization, and Evaluation
# This section predicts voltage values, plots the regression line, and calculates regression evaluation metrics.

# %%
V_pred = model.predict(I_test)

# %%
plt.scatter(I_test, v_test, label="Measured Data")
plt.plot(I_test, V_pred, color="red", label="Regression Line")
plt.xlabel("Current (A)")
plt.ylabel("Voltage (V)")
plt.title("Linear Regression Fit")
plt.grid(True)
plt.legend()
plt.show()

print("Estimated Resistance (slope):", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Estimated Resistance (slope): 999.9998266913688
# Intercept: 4.450382402865216e-05

# %%
# Compute metrics
MAE = mean_absolute_error(v_test, V_pred)
RMSE = np.sqrt(mean_squared_error(v_test, V_pred))

print("MAE:", MAE)
print("RMSE:", RMSE)
# Out:
# MAE: 0.01361293306216554
# RMSE: 0.01648930731912811

# %% [markdown]
# ## Final Conclusion
# In this lab, Linear Regression was applied to a synthetic Ohm's Law dataset. The model learned the relationship between current and voltage and was evaluated using standard regression metrics.
#
# ## Submitted By
# **Student Name:** Malik Awais Bashir
# **Registration Number:** 22JZELE0474
# **Course:** Machine Learning Lab
# **Supervisor:** Engr. Irshad Ullah
# **University:** UET Peshawar - Nowshera Campus
